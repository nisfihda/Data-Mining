# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Tugas 1 Data Integration

# %% [markdown]
# ## Bank Additional

# %%
data1=pd.read_csv("bank1.csv",sep=";")

# %%
data2=pd.read_csv("bank2.csv",sep=";")

# %%
data1
# Out:
#     age            job   marital            education  default  housing  \
# 0    30    blue-collar   married             basic.9y       no      yes
# 1    39       services    single          high.school       no       no
# 2    25       services   married          high.school       no      yes
# 3    38       services   married             basic.9y       no  unknown
# 4    47         admin.   married    university.degree       no      yes
# 5    32       services    single    university.degree       no       no
# 6    32         admin.    single    university.degree       no      yes
# 7    41   entrepreneur   married    university.degree  unknown      yes
# 8    31       services  divorced  professional.course       no       no
# 9    35    blue-collar   married             basic.9y  unknown       no
# 10   25       services    single             basic.6y  unknown      yes
# 11   36  self-employed    single             basic.4y       no       no
# ...

# %%
data2
# Out:
#     age month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0    30   may         fri       487         2    999         0  nonexistent
# 1    39   may         fri       346         4    999         0  nonexistent
# 2    25   jun         wed       227         1    999         0  nonexistent
# 3    38   jun         fri        17         3    999         0  nonexistent
# 4    47   nov         mon        58         1    999         0  nonexistent
# 5    32   sep         thu       128         3    999         2      failure
# 6    32   sep         mon       290         4    999         0  nonexistent
# 7    41   nov         mon        44         2    999         0  nonexistent
# 8    31   nov         tue        68         1    999         1      failure
# 9    35   may         thu       170         1    999         0  nonexistent
# 10   25   jul         thu       301         1    999         0  nonexistent
# ...

# %%
data=pd.merge(data1, data2, on="age")

# %%
data
# Out:
#      age            job   marital            education  default housing loan  \
# 0     30    blue-collar   married             basic.9y       no     yes   no
# 1     30    blue-collar   married             basic.9y       no     yes   no
# 2     30    blue-collar   married             basic.9y       no     yes   no
# 3     30    blue-collar    single             basic.4y  unknown     yes   no
# 4     30    blue-collar    single             basic.4y  unknown     yes   no
# 5     30    blue-collar    single             basic.4y  unknown     yes   no
# 6     30    blue-collar    single             basic.6y       no     yes   no
# 7     30    blue-collar    single             basic.6y       no     yes   no
# 8     30    blue-collar    single             basic.6y       no     yes   no
# 9     39       services    single          high.school       no      no   no
# 10    39       services    single          high.school       no      no   no
# ...
